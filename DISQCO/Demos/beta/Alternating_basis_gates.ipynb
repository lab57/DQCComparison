# %% [markdown]
# # Alternating basis gates
#
# This notebook serves to compare the performance of using different basis gates in the partitioning process.
#
# More specifically, there are different options available to achieve a desired gate set in the final circuit.
#
# ## Pre-partitioning transpilation
#
# One option is to choose the desired gate set from the start, and build the graphical circuit based on this.
# *Advantages*:
# - Optimisation can be performed globally across the circuit, since there will be no immutable entanglement blocks separating different sections of the circuit. This could result in lower circuit depth.
#
# *Disadvantages*:
# - Using $CX$ or $CZ$ gates instead of $CP$ gates may increase the number of two-qubit gates, and likely the number of e-bits required too.
# - Decomposing $U$ gates will result in deep circuits corresponding to larger problem instances for partitioning.
#
# ## Post-partitioning transpilation
#
# Alternatively, we partition using the general $[U, CP]$ gate set, and then only transpile the rest of the circuit after we have partitioned and inserted our teleportation instructions.
#
# *Advantages*:
# - The temporal hypergraph framework is designed to work with the $U$ and $CP$ gate set, since this allows us to compress many gates into one, so reduces the size of the partitioning problem.
# - $CP$ gates are symmetric and so give greater potential for gate grouping - this usually results in lower e-bit costs, which is the main target of the optimisation.
# - Since we will likely have to recompile for intra-QPU routing anyway, we can combine these together.
#
# *Disadvantages*:
# - When transpiling after partitioning, we are more restricted since entanglement generation blocks must be made immutable to keep within our QPU constraints. This often means our sub-circuits are deeper than they could be (though this is negated if entanglement generation and distribution dominates the run time).
# - Potentially avoid an extra transpilation step.
#
# We will compare these on a couple of examples.

# %% [markdown]
# ## Pre-partitioning transpilation

# %%
from qiskit.circuit.library import QFT
from disqco.circuits.cp_fraction import cp_fraction, cz_fraction
from qiskit import transpile
from QASMBench.interface.qiskit import QASMBenchmark
from disqco.graphs.quantum_network import QuantumNetwork


num_qubits = 16

circuit = cp_fraction(num_qubits, num_qubits, fraction=0.5, seed=424)

# circuit = QFT(num_qubits, do_swaps=False)


num_partitions = 4 # Define the number of partitions or QPUs you will distribute over
depth = circuit.depth()

qpu_size = num_qubits // num_partitions + 1 # Define the number of qubits per QPU. For simplicity, we divide qubits evenly and add one additional space to each for teleportation (an extra space is needed for the teleportation qubit so the algorithmr requires it!)
qpu_sizes = [qpu_size] * num_partitions # Store the number of qubits per QPU in a list


# If we do not specificy the connectivity, we have all-to-all by default.

quantum_network = QuantumNetwork(qpu_sizes)


basis_gates = ['cp', 'u']


circuit = transpile(circuit, basis_gates=basis_gates)

print(f'Number of qubits in circuit {circuit.num_qubits}')
print(f'Circuit depth: {circuit.depth()}')

# circuit.draw('mpl', fold = 100, style='bw')
# Out:
# Number of qubits in circuit 16
# Circuit depth: 16

# %%
from disqco.graphs.GCP_hypergraph import QuantumCircuitHyperGraph
from disqco.parti.FM.FM_methods import set_initial_partitions

depth = circuit.depth() # Get the depth of the circuit

graph = QuantumCircuitHyperGraph(circuit, group_gates=True, anti_diag=True, map_circuit=True)

assignment = set_initial_partitions(quantum_network, num_qubits, depth, False)
# Out:
# Number of layers: 18

# %% [markdown]
# If you want to look at the graph, you can use the following code to draw it. It's just something that's been thrown together so doesn't work very well and you have to play around with the scale but it can be useful to see what's going on.

# %%
from disqco.drawing.tikz_drawing import draw_graph_tikz
from disqco.drawing.mpl_drawing import draw_graph_mpl

# %load_ext jupyter_tikz

if num_qubits <= 32 and depth <= 100:
    fig = draw_graph_tikz(graph, assignment, qpu_sizes)
    display(fig)
else:
    fig = draw_graph_mpl(graph, assignment, qpu_sizes)
# Out:
# The jupyter_tikz extension is already loaded. To reload it, use:
#   %reload_ext jupyter_tikz

# %%
from disqco.parti.FM.multilevel_FM import MLFM_recursive
import numpy as np
import time

start = time.time()
assignment_list_MLFMR, cost_list_MLFMR, _ = MLFM_recursive(graph,
                                        assignment,  
                                        qpu_sizes,
                                        limit=num_qubits,
                                        log = True)
end = time.time()

print(f'Time taken for MLFM: {end - start} seconds')

final_cost_CP_U = min(cost_list_MLFMR)
final_assignment_CP_U = assignment_list_MLFMR[np.argmin(cost_list_MLFMR)]
# Out:
# Number of layers: 18
# Number of layers: 18
# Number of layers: 18
# Number of layers: 18
# Initial cost: 41
# All passes complete.
# Final cost: 25
# Best cost at level 0: 25
# Initial cost: 25
# All passes complete.
# Final cost: 23
# Best cost at level 1: 23
# Initial cost: 23
# All passes complete.
# Final cost: 22
# Best cost at level 2: 22
# Initial cost: 22
# All passes complete.
# Final cost: 22
# Best cost at level 3: 22
# Initial cost: 22
# All passes complete.
# Final cost: 21
# Best cost at level 4: 21
# Time taken for MLFM: 0.11752581596374512 seconds

# %%
from disqco.circuit_extraction.circuit_extractor import PartitionedCircuitExtractor

extractor = PartitionedCircuitExtractor(graph=graph, 
                                        partition_assignment=final_assignment_CP_U, 
                                        qpu_info=qpu_sizes, 
                                        comm_info=[2]*num_partitions)

extracted_circuit = extractor.extract_partitioned_circuit()
# Out:
# gate: {'type': 'single-qubit', 'name': 'u', 'qargs': [0], 'qregs': ['q'], 'params': [1.885363034304217, -3.012528685967067, 0.3664717830237043]}
# gate: {'type': 'single-qubit', 'name': 'u', 'qargs': [1], 'qregs': ['q'], 'params': [1.3268678168824746, 1.8107404565703131, -1.8593456834357782]}
# gate: {'type': 'single-qubit', 'name': 'u', 'qargs': [2], 'qregs': ['q'], 'params': [4.696493281830648, 4.153612441228078, 1.250943974407409]}
# gate: {'type': 'single-qubit', 'name': 'u', 'qargs': [5], 'qregs': ['q'], 'params': [1.7198194671342604, 5.640024718960963, 2.8064668104194688]}
# gate: {'type': 'single-qubit', 'name': 'u', 'qargs': [6], 'qregs': ['q'], 'params': [2.38951904512182, 5.249431118502132, 4.574064737444528]}
# gate: {'type': 'single-qubit', 'name': 'u', 'qargs': [8], 'qregs': ['q'], 'params': [0.22117705918250855, 0.3368872696147829, 2.674011207056081]}
# gate: {'type': 'single-qubit', 'name': 'u', 'qargs': [10], 'qregs': ['q'], 'params': [2.1913052511435755, -2.2028754059072564, 0.06284730535413985]}
# gate: {'type': 'single-qubit', 'name': 'u', 'qargs': [11], 'qregs': ['q'], 'params': [1.4217714515293802, 3.990659422947886, 1.9607257498525499]}
# gate: {'type': 'single-qubit', 'name': 'u', 'qargs': [14], 'qregs': ['q'], 'params': [0.8943097515635468, 5.484370839093696, 0.39227363542001303]}
# gate: {'type': 'single-qubit', 'name': 'u', 'qargs': [15], 'qregs': ['q'], 'params': [4.870749586231558, 3.718236674037739, 3.0531300511347075]}
# gate: {'type': 'two-qubit', 'name': 'cp', 'qargs': [3, 12], 'qregs': ['q', 'q'], 'params': [2.8296727130201633], 'time': 0}
# gate: {'type': 'two-qubit', 'name': 'cp', 'qargs': [9, 7], 'qregs': ['q', 'q'], 'params': [3.354274716683551], 'time': 0}
# gate: {'type': 'two-qubit', 'name': 'cp', 'qargs': [13, 4], 'qregs': ['q', 'q'], 'params': [2.340360265601851], 'time': 0}
# gate: {'type': 'single-qubit', 'name': 'u', 'qargs': [7], 'qregs': ['q'], 'params': [4.771938485794689, 5.45957608367089, 6.083922750472033]}
# gate: {'type': 'single-qubit', 'name': 'u', 'qargs': [12], 'qregs': ['q'], 'params': [4.569383983167398, 0.9215030334803068, 3.7969445377410542]}
# gate: {'type': 'single-qubit', 'name': 'u', 'qargs':
}
# gate: {'type': 'single-qubit', 'name': 'u', 'qargs': [8], 'qregs': ['q'], 'params': [3.654082591176481, 0.5152369141034224, 0.8161417704226688]}
# gate: {'type': 'single-qubit', 'name': 'u', 'qargs': [11], 'qregs': ['q'], 'params': [5.01683092060766, 4.00920109265084, 1.0869772186143063]}
# gate: {'type': 'two-qubit', 'name': 'cp', 'qargs': [2, 5], 'qregs': ['q', 'q'], 'params': [0.4320119084467041]}
# gate: {'type': 'two-qubit', 'name': 'cp', 'qargs': [0, 14], 'qregs': ['q', 'q'], 'params': [3.4084775693321414]}
# gate: {'type': 'two-qubit-linked', 'name': 'cp', 'qargs': [3, 9], 'params': [2.096868494961879], 'time': 15}

# %%
from qiskit.transpiler.passes.synthesis import SolovayKitaev
from qiskit.transpiler import PassManager
from qiskit.synthesis import SolovayKitaevDecomposition, generate_basic_approximations
from qiskit.converters import circuit_to_dag, dag_to_circuit
from qiskit.circuit.library import UGate
from qiskit.quantum_info import Operator

final_circuit_U_CP_EPR = transpile(extracted_circuit, basis_gates=basis_gates + ['EPR'])

basis_gates_unary = ['h', 's', 't', 'tdg']
basis_gates_binary = ['cx']
clifford_T = basis_gates_unary + basis_gates_binary


def transpile_partitioned_circuit(circuit, basis_gates_unary, basis_gates_binary, approx_depth=2, skd_degree=2):
    """Transpile the partitioned circuit to the specified basis gates."""
    basic_approx = generate_basic_approximations(basis_gates=basis_gates_unary, depth=approx_depth, )
    skd = SolovayKitaevDecomposition(basic_approximations=basic_approx)

    final_circuit = transpile(circuit, basis_gates=['u'] + basis_gates_binary + ['EPR'])
    dag = circuit_to_dag(final_circuit)

    for node in list(dag.op_nodes(op=UGate)):
        matrix = Operator(node.op).to_matrix()
        # Normalize the matrix to ensure it is a valid quantum gate
        matrix /= np.sqrt(np.linalg.det(matrix))
        replacement = skd.run(matrix, recursion_degree=skd_degree)
        replacement_dag = circuit_to_dag(replacement)
        dag.substitute_node_with_dag(node, replacement_dag)
    
    final_circuit = dag_to_circuit(dag)
    return final_circuit



final_circuit = transpile_partitioned_circuit(final_circuit_U_CP_EPR, basis_gates_unary=basis_gates_unary, basis_gates_binary=basis_gates_binary)

print(f'Final circuit depth after post-partitioning transpilation: {final_circuit.depth()}')

print("Number of EPR pairs in partitioned circuit: ", final_circuit_U_CP_EPR.count_ops().get('EPR', 0))

# final_circuit.draw('mpl', fold=100, style='bw')
# Out:
# Final circuit depth after post-partitioning transpilation: 355
# Number of EPR pairs in partitioned circuit:  21

# %% [markdown]
# ## Pre-partitioning tranpsilation
#
# Compare this with building our graph from a pre-transpiled circuit into the Clifford + T basis. Nodes representing target qubits are shown as white, to highlight the asymmetry of these edges. We expect to see a much larger graph than previously.

# %%
circuit_clifford = transpile_partitioned_circuit(circuit, basis_gates_unary=basis_gates_unary, basis_gates_binary=basis_gates_binary)
graph = QuantumCircuitHyperGraph(circuit_clifford, group_gates=True, anti_diag=True, map_circuit=True)
print(graph.layers)

assignment = set_initial_partitions(quantum_network, num_qubits, graph.depth, False)

if num_qubits <= 32 and depth <= 100:
    fig = draw_graph_tikz(graph, assignment, qpu_sizes)
    display(fig)
else:
    fig = draw_graph_mpl(graph, assignment, qpu_sizes)
# Out:
# Number of layers: 107
# {0: [{'type': 'single-qubit', 'name': 'tdg', 'qargs': [0], 'qregs': ['q'], 'params': []}, {'type': 'single-qubit', 'name': 's', 'qargs': [1], 'qregs': ['q'], 'params': []}, {'type': 'single-qubit', 'name': 'h', 'qargs': [2], 'qregs': ['q'], 'params': []}, {'type': 'single-qubit', 'name': 't', 'qargs': [4], 'qregs': ['q'], 'params': []}, {'type': 'single-qubit', 'name': 'h', 'qargs': [5], 'qregs': ['q'], 'params': []}, {'type': 'single-qubit', 'name': 's', 'qargs': [6], 'qregs': ['q'], 'params': []}, {'type': 'single-qubit', 'name': 's', 'qargs': [8], 'qregs': ['q'], 'params': []}, {'type': 'single-qubit', 'name': 's', 'qargs': [9], 'qregs': ['q'], 'params': []}, {'type': 'single-qubit', 'name': 's', 'qargs': [10], 'qregs': ['q'], 'params': []}, {'type': 'single-qubit', 'name': 'tdg', 'qargs': [11], 'qregs': ['q'], 'params': []}, {'type': 'single-qubit', 'name': 's', 'qargs': [12], 'qregs': ['q'], 'params': []}, {'type': 'single-qubit', 'name': 'tdg', 'qargs': [14], 'qregs': ['q'], 'params': []}, {'type': 'single-qubit', 'name': 't', 'qargs': [15], 'qregs': ['q'], 'params': []}], 1: [{'type': 'single-qubit', 'name': 'tdg', 'qargs': [0], 'qregs': ['q'], 'params': []}, {'type': 'single-qubit', 'name': 's', 'qargs': [2], 'qregs': ['q'], 'params': []}, {'type': 'single-qubit', 'name': 'tdg', 'qargs': [5], 'qregs': ['q'], 'params': []}, {'type': 'single-qubit', 'name': 'h', 'qargs': [6], 'qregs': ['q'], 'params': []}, {'type': 'single-qubit', 'name': 's', 'qargs': [8], 'qregs': ['q'], 'params': []}, {'type': 'single-qubit', 'name': 'h', 'qargs': [10], 'qregs': ['q'], 'params': []}, {'type': 'single-qubit', 'name': 'h', 'qargs': [11], 'qregs': ['q'], 'params': []}, {'type': 'group', 'root': 4, 'time': 1, 'sub-gates': [{'type': 'two-qubit', 'name': 'cx', 'qargs': [4, 13], 'qregs': ['q', 'q'], 'params': [], 'time': 1}, {'type': 'two-qubit', 'name': 'cx', 'qargs': [4, 13], 'qregs': ['q', 'q'], 'params': [], 'time': 3}]}, {'type': 'group', 'root': 12, 'time': 1, 'sub-gates': [{'type': 'two-qubit', 'name': 'cx', 'qargs': [12, 3], 'qregs': ['q', 'q'], 'params': [], 'time': 1}, {'type': 'two-qubit', 'name': 'cx', 'qargs': [12, 3], 'qregs': ['q', 'q'], 'params': [], 'time': 4}, {'type': 'single-qubit', 'name': 's', 'qargs': [12], 'qregs': ['q'], 'params': [], 'time': 5}, {'type': 'single-qubit', 'name': 'tdg', 'qargs': [12], 'qregs': ['q'], 'params': [], 'time': 6}, {'type': 'single-qubit', 'name': 'sdg', 'qargs': [12], 'qregs': ['q'], 'params': [], 'time': 7}]}, {'type': 'group', 'root': 9, 'time': 1, 'sub-gates': [{'type': 'two-qubit', 'name': 'cx', 'qargs': [9, 7], 'qregs': ['q', 'q'], 'params': [], 'time': 1}, {'type': 'two-qubit', 'name': 'cx', 'qargs': [9, 7], 'qregs': ['q', 'q'], 'params': [], 'time': 4}, {'type': 'single-qubit', 'name': 's', 'qargs': [9], 'qregs': ['q'], 'params': [], 'time': 5}, {'type': 'two-qubit', 'name': 'cx', 'qargs': [9, 14], 'qregs': ['q', 'q'], 'params': [], 'time': 6}, {'type': 'two-qubit', 'name': 'cx', 'qargs': [9, 14], 'qregs': ['q', 'q'], 'params': [], 'time': 9}, {'type': 'single-qubit', 'name': 's', 'qargs': [9], 'qregs': ['q'], 'params': [], 'time': 10}, {'type': 'single-qubit', 'name': 't', 'qargs': [9], 'qregs': ['q'], 'params': [], 'time': 11}]}], 2: [{'type': 'single-qubit', 'name': 'sdg', 'qargs': [0], 'qregs': ['q'], 'params': []}, {'type': 'single-qubit', 'name': 'tdg', 'qargs': [2], 'qregs': ['q'], 'params': []}, {'type': 'single-qubit', 'name': 'tdg', 'qargs': [13], 'qregs': ['q'], 'params': []}, {'type': 'single-qubit', 'name': 'tdg', 'qargs': [7], 'qregs': ['q'], 'params': []}, {'type': 'single-qubit', 'name': 'sdg', 'qargs': [10], 'qregs': ['q'], 'params': []}, {'type': 'single-qubit', 'name': 'tdg', 'qargs': [3], 'qregs': ['q'], 'params': []}, {'type': 'group', 'root': 11, 'time': 2, 'sub-gates': [{'type': 'two-qubit', 'name': 'cx', 'qargs': [11, 6], 'qregs': ['q', 'q'], 'params': [], 'time': 2}, {'type': 'two-qubit', 'name': 'cx', 'qargs': [11, 6], 'qregs': ['q', 'q'], 'params': [], 'ti ...

# %%
assignment_list, cost_list, _ = MLFM_recursive(graph,
                                        assignment,
                                        qpu_sizes,
                                        limit=num_qubits,
                                        log = True)

assignment = assignment_list[np.argmin(cost_list)]


extractor = PartitionedCircuitExtractor(graph=graph,
                                        partition_assignment=assignment, 
                                        qpu_info=qpu_sizes, 
                                        comm_info=[2]*num_partitions)


final_circuit = extractor.extract_partitioned_circuit()

final_circuit = transpile(final_circuit, basis_gates = clifford_T + ['EPR'])


depth = final_circuit.depth()

print(f'Final circuit depth after partitioning: {depth}')

print(f'Number of EPR pairs in partitioned circuit: {final_circuit.count_ops()["EPR"]}')
# Out:
# Number of layers: 107
# Number of layers: 107
# Number of layers: 107
# Number of layers: 107
# Number of layers: 107
# Number of layers: 107
# Number of layers: 107
# Initial cost: 44
# All passes complete.
# Final cost: 26
# Best cost at level 0: 26
# Initial cost: 26
# All passes complete.
# Final cost: 26
# Best cost at level 1: 26
# Initial cost: 26
# All passes complete.
# Final cost: 26
# Best cost at level 2: 26
# Initial cost: 26
# All passes complete.
# Final cost: 26
# Best cost at level 3: 26
# Initial cost: 26
# All passes complete.
# Final cost: 26
# Best cost at level 4: 26
# Initial cost: 26
# All passes complete.
# Final cost: 26
# Best cost at level 5: 26
# Initial cost: 26
# All passes complete.
# Final cost: 26
# Best cost at level 6: 26
# Initial cost: 26
# All passes complete.
# Final cost: 26
# Best cost at level 7: 26
# gate: {'type': 'single-qubit', 'name': 'tdg', 'qargs': [0], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 's', 'qargs': [1], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'h', 'qargs': [2], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 't', 'qargs': [4], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'h', 'qargs': [5], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 's', 'qargs': [6], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 's', 'qargs': [8], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 's', 'qargs': [9], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 's', 'qargs': [10], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'tdg', 'qargs': [11], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 's', 'qargs': [12], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'tdg', 'qargs': [14], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 't', 'qargs': [15], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'tdg', 'qargs': [0], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 's', 'qargs': [2], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'tdg', 'qargs': [5], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'h', 'qargs': [6], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 's', 'qargs': [8], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'h', 'qargs': [10], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'h', 'qargs': [11], 'qregs': ['q'], 'params': []}
# gate: {'type': 'two-qubit', 'name': 'cx', 'qargs': [4, 13], 'qregs': ['q', 'q'], 'params': [], 'time': 1}
# gate: {'type': 'two-qubit', 'name': 'cx', 'qargs': [12, 3], 'qregs': ['q', 'q'], 'params': [], 'time': 1}
# gate: {'type': 'two-qubit', 'name': 'cx', 'qargs': [9, 7], 'qregs': ['q', 'q'], 'params': [], 'time': 1}
# gate: {'type': 'single-qubit', 'name': 'sdg', 'qargs': [0], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'tdg', 'qargs': [2], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'tdg', 'qargs': [13], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'tdg', 'qargs': [7], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'sdg', 'qargs': [10], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'tdg', 'qargs': [3], 'qregs': ['q'], 'params': []}
# gate: {'type': 'two-qubit', 'name': 'cx', 'qargs': [11, 6], 'qregs': ['q', 'q'], 'params': [], 'time': 2}
# gate: {'type': 'two-qubit', 'name': 'cx', 'qargs': [1, 8], 'qregs': ['q', 'q'], 'params': [], 'time': 2}
# gate: {'type': 'single-qubit', 'name': 'h', 'qargs': [0], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'h', 'qargs': [2], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'tdg', 'qargs': [8], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'tdg', 'qargs': [7], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'h', 'qargs': [10], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'tdg', 'qargs': [6], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'tdg', 'qargs': [3], 'qregs': ['q'], 'params': []}
# gate: {'type': 'two-qubit-linked', 'name': 'cx', 'qargs': [4, 13], 'params': [], 'time': 3}
# gate: {'type': 'single-qubit', 'name': 'tdg', 'qargs': [0], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'sdg', 'qargs': [2], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'h', 'qargs': [4], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 't', 'qargs': [13], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'tdg', 'qargs': [8], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'sdg', 'qargs': [10], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'tdg', 'qargs': [6], 'qregs': ['q'], 'params': []}
# gate: {'type': 'two-qubit-linked', 'name': 'cx', 'qargs': [12, 3], 'params': [], 'time': 4}
# gate: {'type': 'two-qubit-linked', 'name': 'cx', 'qargs': [9, 7], 'params': [], 'time': 4}
# gate: {'type': 'single-qubit', 'name': 'h', 'qargs': [0], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 't', 'qargs': [2], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 's', 'qargs': [4], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 't', 'qargs': [7], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'tdg', 'qargs': [10], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 's', 'qargs': [3], 'qregs': ['q'], 'params': []}
# gate: {'type': 'two-qubit', 'name': 'cx', 'qargs': [Qubit(QuantumRegister(2, 'C0_0'), 0), 13], 'qregs': ['q', 'q'], 'params': [], 'time': 5}
# gate: {'type': 'single-qubit', 'name': 's', 'qargs': [12], 'qregs': ['q'], 'params': [], 'time': 5}
# gate: {'type': 'single-qubit', 'name': 's', 'qargs': [9], 'qregs': ['q'], 'params': [], 'time': 5}
# gate: {'type': 'two-qubit-linked', 'name': 'cx', 'qargs': [11, 6], 'params': [], 'time': 5}
# gate: {'type': 'two-qubit-linked', 'name': 'cx', 'qargs': [1, 8], 'params': [], 'time': 5}
# gate: {'type': 'single-qubit', 'name': 's', 'qargs': [0], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 's', 'qargs': [2], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'h', 'qargs': [8], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 's', 'qargs': [10], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 's', 'qargs': [6], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'tdg', 'qargs': [12], 'qregs': ['q'], 'params': [], 'time': 6}
# gate: {'type': 'two-qubit-linked', 'name': 'cx', 'qargs': [9, 14], 'params': [], 'time': 6}
# gate: {'type': 'single-qubit', 'name': 's', 'qargs': [1], 'qregs': ['q'], 'params': [], 'time': 6}
# gate: {'type': 'two-qubit-linked', 'name': 'cx', 'qargs': [Qubit(QuantumRegister(2, 'C0_0'), 0), 13], 'params': [], 'time': 6}
# gate: {'type': 'single-qubit', 'name': 't', 'qargs': [0], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'h', 'qargs': [2], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'tdg', 'qargs': [8], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'tdg', 'qargs': [14], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'h', 'qargs': [10], 'qregs': ['q'], 'params': []}
# gate: {'type': 'two-qubit', 'name': 'cx', 'qargs': [Qubit(QuantumRegister(2, 'C1_0'), 1), 15], 'qregs': ['q', 'q'], 'params': [], 'time': 7}
# gate: {'type': 'single-qubit', 'name': 'sdg', 'qargs': [12], 'qregs': ['q'], 'params': [], 'time': 7}
# gate: {'type': 'single-qubit', 'name': 't', 'qargs': [1], 'qregs': ['q'], 'params': [], 'time': 7}
# gate: {'type': 'single-qubit', 'name': 'tdg', 'qargs': [15], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'tdg', 'qargs': [14], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 't', 'qargs': [10], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'h', 'qargs': [12], 'qregs': ['q'], 'params': []}
# gate: {'type': 'two-qubit', 'name': 'cx', 'qargs': [Qubit(QuantumRegister(2, 'C1_0'), 0), 11], 'qregs': ['q', 'q'], 'params': [], 'time': 8}
# gate: {'type': 'two-qubit', 'name': 'cx', 'qargs': [Qubit(QuantumRegister(1, 'C1_1'), 0), 3], 'qregs': ['q', 'q'], 'params': [], 'time': 8}
# gate: {'type': 'single-qubit', 'name': 'tdg', 'qargs': [11], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 's', 'qargs': [10], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 't', 'qargs': [12], 'qregs': ['q'], 'params': []}
# gate: {'type': 'two-qubit-linked', 'name': 'cx', 'qargs': [9, 14], 'params': [], 'time': 9}
# gate: {'type': 'two-qubit-linked', 'name': 'cx', 'qargs': [Qubit(QuantumRegister(2, 'C1_0'), 1), 15], 'params': [], 'time': 9}
# gate: {'type': 'two-qubit-linked', 'name': 'cx', 'qargs': [Qubit(QuantumRegister(1, 'C1_1'), 0), 3], 'params': [], 'time': 9}
# gate: {'type': 'single-qubit', 'name': 't', 'qargs': [3], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 't', 'qargs': [15], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 's', 'qargs': [14], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'tdg', 'qargs': [10], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'h', 'qargs': [12], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 's', 'qargs': [9], 'qregs': ['q'], 'params': [], 'time': 10}
# gate: {'type': 'two-qubit-linked', 'name': 'cx', 'qargs': [Qubit(QuantumRegister(2, 'C1_0'), 0), 11], 'params': [], 'time': 10}
# gate: {'type': 'single-qubit', 'name': 's', 'qargs': [2], 'qregs': ['q'], 'params': [], 'time': 10}
# gate: {'type': 'single-qubit', 'name': 's', 'qargs': [11], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'h', 'qargs': [0], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'h', 'qargs': [3], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'h', 'qargs': [2], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 's', 'qargs': [14], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'h', 'qargs': [10], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 's', 'qargs': [12], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 't', 'qargs': [9], 'qregs': ['q'], 'params': [], 'time': 11}
# gate: {'type': 'single-qubit', 'name': 't', 'qargs': [11], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'tdg', 'qargs': [0], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'sdg', 'qargs': [10], 'qregs': ['q'], 'params': []}
# gate: {'type': 'two-qubit', 'name': 'cx', 'qargs': [Qubit(QuantumRegister(2, 'C2_0'), 1), 7], 'qregs': ['q', 'q'], 'params': [], 'time': 12}
# gate: {'type': 'two-qubit', 'name': 'cx', 'qargs': [2, 4], 'qregs': ['q', 'q'], 'params': [], 'time': 12}
# gate: {'type': 'two-qubit', 'name': 'cx', 'qargs': [14, 5], 'qregs': ['q', 'q'], 'params': [], 'time': 12}
# gate: {'type': 'single-qubit', 'name': 's', 'qargs': [4], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 's', 'qargs': [5], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 't', 'qargs': [10], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 's', 'qargs': [7], 'qregs': ['q'], 'params': []}
# gate: {'type': 'two-qubit', 'name': 'cx', 'qargs': [Qubit(QuantumRegister(2, 'C2_0'), 0), 9], 'qregs': ['q', 'q'], 'params': [], 'time': 13}
# gate: {'type': 'single-qubit', 'name': 'tdg', 'qargs': [9], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 's', 'qargs': [4], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 's', 'qargs': [5], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 's', 'qargs': [10], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 's', 'qargs': [7], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'tdg', 'qargs': [9], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'h', 'qargs': [10], 'qregs': ['q'], 'params': []}
# gate: {'type': 'two-qubit-linked', 'name': 'cx', 'qargs': [Qubit(QuantumRegister(2, 'C2_0'), 1), 7], 'params': [], 'time': 15}
# gate: {'type': 'two-qubit-linked', 'name': 'cx', 'qargs': [2, 4], 'params': [], 'time': 15}
# gate: {'type': 'two-qubit-linked', 'name': 'cx', 'qargs': [14, 5], 'params': [], 'time': 15}
# gate: {'type': 'single-qubit', 'name': 'tdg', 'qargs': [5], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 's', 'qargs': [7], 'qregs': ['q'], 'params': []}
# gate: {'type': 'two-qubit', 'name': 'cx', 'qargs': [10, 13], 'qregs': ['q', 'q'], 'params': [], 'time': 16}
# gate: {'type': 'two-qubit-linked', 'name': 'cx', 'qargs': [Qubit(QuantumRegister(2, 'C1_0'), 0), 12], 'params': [], 'time': 16}
# gate: {'type': 'single-qubit', 'name': 's', 'qargs': [14], 'qregs': ['q'], 'params': [], 'time': 16}
# gate: {'type': 'two-qubit-linked', 'name': 'cx', 'qargs': [Qubit(QuantumRegister(2, 'C2_0'), 0), 9], 'params': [], 'time': 16}
# gate: {'type': 'single-qubit', 'name': 'tdg', 'qargs': [9], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'tdg', 'qargs': [13], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'tdg', 'qargs': [12], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 's', 'qargs': [7], 'qregs': ['q'], 'params': []}
# gate: {'type': 'two-qubit', 'name': 'cx', 'qargs': [Qubit(QuantumRegister(2, 'C1_0'), 1), 15], 'qregs': ['q', 'q'], 'params': [], 'time': 17}
# gate: {'type': 'single-qubit', 'name': 't', 'qargs': [14], 'qregs': ['q'], 'params': [], 'time': 17}
# gate: {'type': 'single-qubit', 'name': 't', 'qargs': [11], 'qregs': ['q'], 'params': [], 'time': 17}
# gate: {'type': 'single-qubit', 'name': 'h', 'qargs': [9], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'h', 'qargs': [11], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 's', 'qargs': [15], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'tdg', 'qargs': [13], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'tdg', 'qargs': [12], 'qregs': ['q'], 'params': []}
# gate: {'type': 'two-qubit-linked', 'name': 'cx', 'qargs': [14, 7], 'params': [], 'time': 18}
# gate: {'type': 'single-qubit', 'name': 's', 'qargs': [15], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 's', 'qargs': [7], 'qregs': ['q'], 'params': []}
# gate: {'type': 'two-qubit-linked', 'name': 'cx', 'qargs': [Qubit(QuantumRegister(2, 'C1_0'), 0), 12], 'params': [], 'time': 19}
# gate: {'type': 'two-qubit-linked', 'name': 'cx', 'qargs': [10, 13], 'params': [], 'time': 19}
# gate: {'type': 'single-qubit', 'name': 's', 'qargs': [13], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'h', 'qargs': [12], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'h', 'qargs': [1], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 's', 'qargs': [7], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'tdg', 'qargs': [10], 'qregs': ['q'], 'params': [], 'time': 20}
# gate: {'type': 'two-qubit-linked', 'name': 'cx', 'qargs': [Qubit(QuantumRegister(2, 'C1_0'), 1), 15], 'params': [], 'time': 20}
# gate: {'type': 'single-qubit', 'name': 'h', 'qargs': [5], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 's', 'qargs': [15], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 't', 'qargs': [13], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'h', 'qargs': [10], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 't', 'qargs': [12], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'tdg', 'qargs': [1], 'qregs': ['q'], 'params': []}
# gate: {'type': 'two-qubit-linked', 'name': 'cx', 'qargs': [14, 7], 'params': [], 'time': 21}
# gate: {'type': 'single-qubit', 'name': 's', 'qargs': [5], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 's', 'qargs': [15], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 't', 'qargs': [13], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 's', 'qargs': [7], 'qregs': ['q'], 'params': []}
# gate: {'type': 'two-qubit', 'name': 'cx', 'qargs': [1, 8], 'qregs': ['q', 'q'], 'params': [], 'time': 22}
# gate: {'type': 'two-qubit', 'name': 'cx', 'qargs': [10, 2], 'qregs': ['q', 'q'], 'params': [], 'time': 22}
# gate: {'type': 'single-qubit', 'name': 's', 'qargs': [14], 'qregs': ['q'], 'params': [], 'time': 22}
# gate: {'type': 'single-qubit', 'name': 't', 'qargs': [13], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'tdg', 'qargs': [2], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'tdg', 'qargs': [8], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 't', 'qargs': [7], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'h', 'qargs': [14], 'qregs': ['q'], 'params': []}
# gate: {'type': 'two-qubit', 'name': 'cx', 'qargs': [6, 15], 'qregs': ['q', 'q'], 'params': [], 'time': 23}
# gate: {'type': 'single-qubit', 'name': 'tdg', 'qargs': [15], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'sdg', 'qargs': [13], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'tdg', 'qargs': [2], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'tdg', 'qargs': [8], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'tdg', 'qargs': [14], 'qregs': ['q'], 'params': []}
# gate: {'type': 'two-qubit', 'name': 'cx', 'qargs':

# gate: {'type': 'two-qubit-linked', 'name': 'cx', 'qargs': [Qubit(QuantumRegister(2, 'C1_0'), 0), 12], 'params': [], 'time': 61}
# gate: {'type': 'two-qubit-linked', 'name': 'cx', 'qargs': [5, 9], 'params': [], 'time': 61}
# gate: {'type': 'single-qubit', 'name': 'h', 'qargs': [11], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 's', 'qargs': [9], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 's', 'qargs': [13], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 's', 'qargs': [12], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'tdg', 'qargs': [10], 'qregs': ['q'], 'params': [], 'time': 62}
# gate: {'type': 'single-qubit', 'name': 'tdg', 'qargs': [5], 'qregs': ['q'], 'params': [], 'time': 62}
# gate: {'type': 'single-qubit', 'name': 's', 'qargs': [11], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 's', 'qargs': [9], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 't', 'qargs': [13], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 's', 'qargs': [12], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'h', 'qargs': [10], 'qregs': ['q'], 'params': []}
# gate: {'type': 'two-qubit-linked', 'name': 'cx', 'qargs': [5, 14], 'params': [], 'time': 63}
# gate: {'type': 'single-qubit', 'name': 'tdg', 'qargs': [14], 'qregs': ['q'], 'params': []}
# gate: {'type': 'two-qubit', 'name': 'cx', 'qargs': [Qubit(QuantumRegister(2, 'C1_0'), 1), 6], 'qregs': ['q', 'q'], 'params': [], 'time': 64}
# gate: {'type': 'two-qubit', 'name': 'cx', 'qargs': [12, 15], 'qregs': ['q', 'q'], 'params': [], 'time': 64}
# gate: {'type': 'two-qubit', 'name': 'cx', 'qargs': [13, 10], 'qregs': ['q', 'q'], 'params': [], 'time': 64}
# gate: {'type': 'single-qubit', 'name': 's', 'qargs': [6], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'tdg', 'qargs': [14], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 's', 'qargs': [15], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'tdg', 'qargs': [10], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 's', 'qargs': [6], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 's', 'qargs': [15], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'tdg', 'qargs': [10], 'qregs': ['q'], 'params': []}
# gate: {'type': 'two-qubit-linked', 'name': 'cx', 'qargs': [5, 14], 'params': [], 'time': 66}
# gate: {'type': 'single-qubit', 'name': 's', 'qargs': [14], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'tdg', 'qargs': [5], 'qregs': ['q'], 'params': [], 'time': 67}
# gate: {'type': 'two-qubit-linked', 'name': 'cx', 'qargs': [Qubit(QuantumRegister(2, 'C1_0'), 1), 6], 'params': [], 'time': 67}
# gate: {'type': 'two-qubit-linked', 'name': 'cx', 'qargs': [12, 15], 'params': [], 'time': 67}
# gate: {'type': 'two-qubit-linked', 'name': 'cx', 'qargs': [13, 10], 'params': [], 'time': 67}
# gate: {'type': 'single-qubit', 'name': 'h', 'qargs': [6], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 't', 'qargs': [14], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 't', 'qargs': [15], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 's', 'qargs': [10], 'qregs': ['q'], 'params': []}
# gate: {'type': 'two-qubit', 'name': 'cx', 'qargs': [Qubit(QuantumRegister(2, 'C2_0'), 0), 5], 'qregs': ['q', 'q'], 'params': [], 'time': 68}
# gate: {'type': 'single-qubit', 'name': 't', 'qargs': [9], 'qregs': ['q'], 'params': [], 'time': 68}
# gate: {'type': 'single-qubit', 'name': 't', 'qargs': [13], 'qregs': ['q'], 'params': [], 'time': 68}
# gate: {'type': 'single-qubit', 'name': 'tdg', 'qargs': [6], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'tdg', 'qargs': [5], 'qregs': ['q'], 'params': []}
# gate: {'type': 'two-qubit', 'name': 'cx', 'qargs': [15, 3], 'qregs': ['q', 'q'], 'params': [], 'time': 69}
# gate: {'type': 'two-qubit', 'name': 'cx', 'qargs': [Qubit(QuantumRegister(1, 'C2_1'), 0), 9], 'qregs': ['q', 'q'], 'params': [], 'time': 69}
# gate: {'type': 'single-qubit', 'name': 'tdg', 'qargs': [9], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'h', 'qargs': [6], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'tdg', 'qargs': [5], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'tdg', 'qargs': [3], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'tdg', 'qargs': [9], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'sdg', 'qargs': [6], 'qregs': ['q'], 'params': []}
# gate: {'type': 'two-qubit-linked', 'name': 'cx', 'qargs': [Qubit(QuantumRegister(2, 'C2_0'), 0), 5], 'params': [], 'time': 71}
# gate: {'type': 'two-qubit-linked', 'name': 'cx', 'qargs': [15, 3], 'params': [], 'time': 71}
# gate: {'type': 'single-qubit', 'name': 't', 'qargs': [6], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'tdg', 'qargs': [5], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'h', 'qargs': [1], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 't', 'qargs': [3], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'h', 'qargs': [15], 'qregs': ['q'], 'params': []}
# gate: {'type': 'two-qubit-linked', 'name': 'cx', 'qargs': [Qubit(QuantumRegister(1, 'C2_1'), 0), 9], 'params': [], 'time': 72}
# gate: {'type': 'single-qubit', 'name': 'tdg', 'qargs': [9], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 's', 'qargs': [6], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 't', 'qargs': [1], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 's', 'qargs': [15], 'qregs': ['q'], 'params': []}
# gate: {'type': 'two-qubit-linked', 'name': 'cx', 'qargs': [Qubit(QuantumRegister(2, 'C2_0'), 1), 5], 'params': [], 'time': 73}
# gate: {'type': 'single-qubit', 'name': 's', 'qargs': [8], 'qregs': ['q'], 'params': [], 'time': 73}
# gate: {'type': 'single-qubit', 'name': 'tdg', 'qargs': [9], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'h', 'qargs': [6], 'qregs': ['q'], 'params': []}
# gate: {'type': 'two-qubit-linked', 'name': 'cx', 'qargs': [Qubit(QuantumRegister(2, 'C2_0'), 1), 5], 'params': [], 'time': 74}
# gate: {'type': 'two-qubit-linked', 'name': 'cx', 'qargs': [Qubit(QuantumRegister(1, 'C2_1'), 0), 14], 'params': [], 'time': 74}
# gate: {'type': 'single-qubit', 'name': 'tdg', 'qargs': [14], 'qregs': ['q'], 'params': []}
# gate: {'type': 'two-qubit', 'name': 'cx', 'qargs': [Qubit(QuantumRegister(2, 'C2_0'), 0), 0], 'qregs': ['q', 'q'], 'params': [], 'time': 75}
# gate: {'type': 'two-qubit', 'name': 'cx', 'qargs': [Qubit(QuantumRegister(2, 'C0_0'), 0), 10], 'qregs': ['q', 'q'], 'params': [], 'time': 75}
# gate: {'type': 'single-qubit', 'name': 'tdg', 'qargs': [10], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'tdg', 'qargs': [14], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'tdg', 'qargs': [0], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'tdg', 'qargs': [10], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'tdg', 'qargs': [0], 'qregs': ['q'], 'params': []}
# gate: {'type': 'two-qubit-linked', 'name': 'cx', 'qargs': [Qubit(QuantumRegister(1, 'C2_1'), 0), 14], 'params': [], 'time': 77}
# gate: {'type': 'single-qubit', 'name': 'tdg', 'qargs': [14], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'tdg', 'qargs': [8], 'qregs': ['q'], 'params': [], 'time': 78}
# gate: {'type': 'two-qubit-linked', 'name': 'cx', 'qargs': [Qubit(QuantumRegister(2, 'C2_0'), 0), 0], 'params': [], 'time': 78}
# gate: {'type': 'two-qubit-linked', 'name': 'cx', 'qargs': [Qubit(QuantumRegister(2, 'C0_0'), 0), 10], 'params': [], 'time': 78}
# gate: {'type': 'single-qubit', 'name': 's', 'qargs': [10], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'h', 'qargs': [14], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 't', 'qargs': [0], 'qregs': ['q'], 'params': []}
# gate: {'type': 'two-qubit-linked', 'name': 'cx', 'qargs': [Qubit(QuantumRegister(2, 'C1_0'), 0), 11], 'params': [], 'time': 79}
# gate: {'type': 'single-qubit', 'name': 's', 'qargs': [6], 'qregs': ['q'], 'params': [], 'time': 79}
# gate: {'type': 'single-qubit', 'name': 's', 'qargs': [9], 'qregs': ['q'], 'params': [], 'time': 79}
# gate: {'type': 'single-qubit', 'name': 's', 'qargs': [10], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'tdg', 'qargs': [11], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'h', 'qargs': [6], 'qregs': ['q'], 'params': []}
# gate: {'type': 'two-qubit', 'name': 'cx', 'qargs': [0, 7], 'qregs': ['q', 'q'], 'params': [], 'time': 80}
# gate: {'type': 'two-qubit-linked', 'name': 'cx', 'qargs': [Qubit(QuantumRegister(2, 'C1_0'), 1), 3], 'params': [], 'time': 80}
# gate: {'type': 'single-qubit', 'name': 'tdg', 'qargs': [3], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'tdg', 'qargs': [11], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'sdg', 'qargs': [6], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 's', 'qargs': [7], 'qregs': ['q'], 'params': []}
# gate: {'type': 'two-qubit-linked', 'name': 'cx', 'qargs': [13, 10], 'params': [], 'time': 81}
# gate: {'type': 'single-qubit', 'name': 'tdg', 'qargs': [10], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'h', 'qargs': [6], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 's', 'qargs': [7], 'qregs': ['q'], 'params': []}
# gate: {'type': 'two-qubit-linked', 'name': 'cx', 'qargs': [Qubit(QuantumRegister(2, 'C1_0'), 0), 11], 'params': [], 'time': 82}
# gate: {'type': 'two-qubit-linked', 'name': 'cx', 'qargs': [Qubit(QuantumRegister(2, 'C1_0'), 1), 3], 'params': [], 'time': 82}
# gate: {'type': 'single-qubit', 'name': 't', 'qargs': [3], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'h', 'qargs': [8], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'sdg', 'qargs': [6], 'qregs': ['q'], 'params': []}
# gate: {'type': 'two-qubit-linked', 'name': 'cx', 'qargs': [13, 10], 'params': [], 'time': 83}
# gate: {'type': 'two-qubit-linked', 'name': 'cx', 'qargs': [0, 7], 'params': [], 'time': 83}
# gate: {'type': 'single-qubit', 'name': 't', 'qargs': [10], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 's', 'qargs': [8], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'tdg', 'qargs': [6], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 's', 'qargs': [7], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'tdg', 'qargs': [0], 'qregs': ['q'], 'params': [], 'time': 84}
# gate: {'type': 'single-qubit', 'name': 't', 'qargs': [8], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 's', 'qargs': [6], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 's', 'qargs': [7], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'h', 'qargs': [0], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'sdg', 'qargs': [8], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'h', 'qargs': [6], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'tdg', 'qargs': [0], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'h', 'qargs': [8], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 't', 'qargs': [6], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'sdg', 'qargs': [0], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'tdg', 'qargs': [8], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 's', 'qargs': [6], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 't', 'qargs': [0], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'h', 'qargs': [8], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'tdg', 'qargs': [6], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'h', 'qargs': [0], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 's', 'qargs': [8], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'h', 'qargs': [6], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 's', 'qargs': [0], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'sdg', 'qargs': [6], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 't', 'qargs': [0], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 't', 'qargs': [6], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'h', 'qargs': [0], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 's', 'qargs': [6], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'tdg', 'qargs': [0], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'h', 'qargs': [6], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'sdg', 'qargs': [0], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'h', 'qargs': [0], 'qregs': ['q'], 'params': []}
# gate: {'type': 'two-qubit', 'name': 'cx', 'qargs': [6, 12], 'qregs': ['q', 'q'], 'params': [], 'time': 95}
# gate: {'type': 'single-qubit', 'name': 'tdg', 'qargs': [12], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'sdg', 'qargs': [0], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'h', 'qargs': [0], 'qregs': ['q'], 'params': []}
# gate: {'type': 'two-qubit-linked', 'name': 'cx', 'qargs': [6, 12], 'params': [], 'time': 97}
# gate: {'type': 'single-qubit', 'name': 't', 'qargs': [12], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 's', 'qargs': [0], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'tdg', 'qargs': [6], 'qregs': ['q'], 'params': [], 'time': 98}
# gate: {'type': 'single-qubit', 'name': 'h', 'qargs': [6], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 's', 'qargs': [0], 'qregs': ['q'], 'params': []}
# gate: {'type': 'two-qubit', 'name': 'cx', 'qargs': [Qubit(QuantumRegister(1, 'C1_1'), 0), 12], 'qregs': ['q', 'q'], 'params': [], 'time': 99}
# gate: {'type': 'single-qubit', 'name': 's', 'qargs': [12], 'qregs': ['q'], 'params': []}
# gate: {'type': 'two-qubit', 'name': 'cx', 'qargs': [0, 14], 'qregs': ['q', 'q'], 'params': [], 'time': 100}
# gate: {'type': 'single-qubit', 'name': 's', 'qargs': [12], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'tdg', 'qargs': [14], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 'tdg', 'qargs': [14], 'qregs': ['q'], 'params': []}
# gate: {'type': 'two-qubit-linked', 'name': 'cx', 'qargs': [Qubit(QuantumRegister(1, 'C1_1'), 0), 12], 'params': [], 'time': 102}
# gate: {'type': 'single-qubit', 'name': 's', 'qargs': [12], 'qregs': ['q'], 'params': []}
# gate: {'type': 'two-qubit-linked', 'name': 'cx', 'qargs': [0, 14], 'params': [], 'time': 103}
# gate: {'type': 'single-qubit', 'name': 't', 'qargs': [12], 'qregs': ['q'], 'params': []}
# gate: {'type': 'single-qubit', 'name': 's', 'qargs': [14], 'qregs': ['q'], 'params': []}
# Final circuit depth after partitioning: 246
# Number of EPR pairs in partitioned circuit: 26

# %% [markdown]
# In this case, we see that the final circuit with post-partitioning transpilation is deeper but has fewer e-bits. If e-bit generation time is very slow this should be preferred. However, if we consider e-bit generation as simply another gate in the circuit, then we should prefer the version which transpiles to the required gate set first.
