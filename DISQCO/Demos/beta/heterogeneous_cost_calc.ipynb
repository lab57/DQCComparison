# %%
qpu_sizes = [5,5,5,5,5]

coupling = [(0,1),(1,2),(2,3),(3,4),(4,2),(0,3)]

from MLFM_GCP.graphs.quantum_network import QuantumNetwork

network = QuantumNetwork(qpu_sizes, coupling)

network.draw()

# %%
root_config = [1,0,1,1,1]

rec_config = [1,1,1,1,1]

edges, cost = network.steiner_forest(root_config, rec_config)

print(edges)
print(cost)
# Out:
# {(0, 1)}
# 1
